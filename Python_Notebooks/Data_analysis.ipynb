# %%
import pandas as pd

# %%
#dataframe=pd.read_excel('F38_Labfors_Dataset.xlsx',sheet_name='F38 20240528',header=2)
dataframe=pd.read_csv('F38_Labfors_Dataset.csv')
cols=dataframe.columns
cols=[c.replace(' ','_') for c in cols]
dataframe.columns=cols
dataframe['Date_Time_UTC']= pd.to_datetime(dataframe['Date_Time_UTC'])
dataframe['Date_Local_Time']= pd.to_datetime(dataframe['Date_Local_Time'])
dataframe=dataframe.set_index(['Date_Time_UTC'])
dataframe=dataframe.dropna(axis=1)
# Out:
# /var/folders/qp/t8zszgx56fn2_whd95bfwqz00000gn/T/ipykernel_26971/2104677302.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataframe['Date_Time_UTC']= pd.to_datetime(dataframe['Date_Time_UTC'])
# /var/folders/qp/t8zszgx56fn2_whd95bfwqz00000gn/T/ipykernel_26971/2104677302.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dataframe['Date_Local_Time']= pd.to_datetime(dataframe['Date_Local_Time'])

# %%
dataframe.columns
# Out:
# Index(['Date_Local_Time', 'Batch_Time,_sec', 'Phase', 'Phase_Time,_sec',
#        'Feed,_%', 'Feed,Total_volume,_ml', 'Feed_2,_%',
#        'Feed_2,Total_volume,_ml', 'AntiFoam_Pump,Total_volume,_ml',
#        'Antifoam,_-', 'Base_Pump,Total_volume,_ml',
#        'Acid_Pump,Total_volume,_ml', 'pH', 'pO2_%', 'Temperature,_°C',
#        'Stirrer,_1/min', 'GenericGasAnalyser,Exit_O2_%',
#        'GenericGasAnalyser,Exit_CO2_%', 'Air_Flow,_ml/min', 'Feed_3,_%',
#        'OD,_-', 'GenericBalance,Balance,_g', 'ApproxOD,ODApprox,_-',
#        'CO2flow,ml/min', 'O2flow,ml/min', 'ApproxODMovAv,ApproxODMovAv,_-'],
#       dtype='object')

# %%
CO2=dataframe[['CO2flow,ml/min']]

# %%
CO2.plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
O2=dataframe[['O2flow,ml/min']]

# %%
O2.plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
air_flow=dataframe[['Air_Flow,_ml/min']]

# %%
air_flow.plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
dataframe[['Feed,_%']].plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
dataframe[['GenericGasAnalyser,Exit_CO2_%']].plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
dataframe[['GenericGasAnalyser,Exit_O2_%']].plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
dataframe[['pO2_%']].plot()
# Out:
# <Axes: xlabel='Date_Time_UTC'>

# %%
35*6
# Out:
# 210
